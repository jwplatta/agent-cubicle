# %% [markdown]
# # Algorithms Practice Challenges
#
# **Difficulty:** {{difficulty}}
# **Date:** {{date}}
# **Questions:** {{count}}
# **Subcategories:** {{subcategories}}
#
# ---
#
# Write your solutions in the empty code cells below. Use only the Python standard library.
# Expand the **Solution** section under each challenge to check your answer.

# %%
from collections import deque, Counter, defaultdict, OrderedDict
import heapq
import math
import itertools
from typing import List, Optional, Dict, Tuple, Any

# Helper for testing solutions
def check(actual, expected, label=''):
    prefix = f'{label}: ' if label else ''
    if actual == expected:
        print(f'{prefix}PASS')
    else:
        print(f'{prefix}FAIL — expected {expected!r}, got {actual!r}')

print('Setup complete.')
